# %% [markdown]
# Bienvenido a nuestro primer encuentro en inmersion de datos.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from pandas.core import describe
import numpy as np


inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.tail()
# Out:
#              Tipo                                     Descripcion  \
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 9515             3      2    70                 Kennedy
# 9516             2      2   100  Parque Central Bavaria
# 9517             8      6   383                Restrepo
# 9518             3      2   183                Engativa
# 9519             3      1    52                 Tintala
#
#                                          UPZ          Valor
# 9515                         Kennedy Central  $ 290.000.000
# 9516  SANTA FE: Las Nieves + Sagrado Corazón  $ 670.000.000
# ...

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5110         Casa                    Casa en venta en Kennedy             4
# 6848         Casa                       Casa en venta en Suba             4
# 7339  Apartamento                Apartamento en venta en Bosa             2
# 6218  Apartamento          Apartamento en venta en Cantagallo             3
# 8732  Apartamento       Apartamento en venta en La Candelaria             1
# 9359        Local             Local en venta en Puente Aranda            16
# 7058  Apartamento                Apartamento en venta en Bosa             3
# 1837  Apartamento           Apartamento en venta en Chapinero             1
# 136   Apartamento  Apartamento en venta en Zona Noroccidental             1
# 131   Apartamento  Apartamento en venta en Rafael Uribe Uribe             3
#
#       Banos  Area              Barrio  \
# 5110      2   163             Kennedy
# 6848      3   250                Suba
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[234]
# Out:
# Tipo                                 Apartamento
# Descripcion     Apartamento en venta en Cedritos
# Habitaciones                                   3
# Banos                                          2
# Area                                          66
# Barrio                                  Cedritos
# UPZ                                      Usaquén
# Valor                              $ 310.000.000
# Name: 234, dtype: object

# %%
inmuebles['Valor'][234:237]
# Out:
# 234      $ 310.000.000
# 235      $ 177.500.000
# 236    $ 1.200.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][234:237])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 9038  Apartamento                Apartamento en venta en Suba             3
# 1363  Apartamento             Apartamento en venta en Modelia             3
# 2038  Apartamento      Apartamento en venta en Barrios Unidos             3
# 4053         Casa             Casa en venta en Ciudad Bolívar             2
# 1729  Apartamento             Apartamento en venta en Kennedy             2
# ...           ...                                         ...           ...
# 974   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 7153  Apartamento                Apartamento en venta en Bosa             2
# 2204  Apartamento                Apartamento en venta en Suba             3
# 289   Apartamento       Apartamento en venta en Santa Barbara             3
# 4944  Apartamento      Apartamento en venta en Barrios Unidos             2
#
#       Banos  Area              Barrio  \
# ...

# %%
(inmuebles.Barrio == 'Usaquén')
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Usaquén'))
# Out:
# 1105

# %%
inmuebles_usaquen = (inmuebles.Barrio == 'Usaquén')
type(inmuebles_usaquen)
# Out:
# pandas.core.series.Series

# %%
usaquen = inmuebles[inmuebles_usaquen]
usaquen
# Out:
#              Tipo                      Descripcion  Habitaciones  Banos  Area  \
# 3     Apartamento  Apartamento en venta en Usaquén             3      2   154
# 20    Apartamento  Apartamento en venta en Usaquén             1      2    50
# 30    Apartamento  Apartamento en venta en Usaquén             3      3    66
# 45    Apartamento  Apartamento en venta en Usaquén             2      2    80
# 56    Apartamento  Apartamento en venta en Usaquén             2      2    80
# ...           ...                              ...           ...    ...   ...
# 9352  Apartamento  Apartamento en venta en Usaquén             3      3   130
# 9409         Casa         Casa en venta en Usaquén             6      5   400
# 9420  Apartamento  Apartamento en venta en Usaquén             3      2    94
# 9439  Apartamento  Apartamento en venta en Usaquén             3      4   112
# 9509  Apartamento  Apartamento en venta en Usaquén             3      3   180
#
# ...

# %%
usaquen.Area.mean()
# Out:
# 134.04615384615386

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# Desafios clase 01
# 🐍

# %%
inmuebles.Banos

baños_est = inmuebles.Banos.describe()
baños_est
# Out:
# count    9520.000000
# mean        2.447899
# std         1.255314
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         9.000000
# Name: Banos, dtype: float64

# %%
habitaciones_est = inmuebles.Habitaciones.describe()
habitaciones_est
# Out:
# count    9520.000000
# mean        3.072479
# std         2.049856
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max       110.000000
# Name: Habitaciones, dtype: float64

# %%
area_est = inmuebles.Area.describe()
area_est
# Out:
# count      9520.000000
# mean        146.664706
# std        1731.379622
# min           2.000000
# 25%          57.000000
# 50%          80.000000
# 75%         135.000000
# max      166243.000000
# Name: Area, dtype: float64

# %%
valor_est = inmuebles.Valor.str.replace('$', '')
valor_est
# Out:
# <ipython-input-110-511e9d6de7ca>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   valor_est = inmuebles.Valor.str.replace('$', '')
# 0          360.000.000
# 1          670.000.000
# 2        1.120.000.000
# 3          890.000.000
# 4          970.000.000
#              ...
# 9515       290.000.000
# 9516       670.000.000
# 9517       900.000.000
# 9518       335.000.000
# 9519       144.990.000
# Name: Valor, Length: 9520, dtype: object

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles['Valor'] = inmuebles['Valor'].str.replace('$', '').str.replace('.', '',regex=True)
inmuebles['Valor'] = inmuebles['Valor'].astype(int)
# Out:
# <ipython-input-112-23ad5658e1e0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   inmuebles['Valor'] = inmuebles['Valor'].str.replace('$', '').str.replace('.', '',regex=True)

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
valor_est = inmuebles.Valor.describe()
valor_est
# Out:
# count    9.520000e+03
# mean     6.020624e+08
# std      7.046021e+08
# min      6.000000e+07
# 25%      2.500000e+08
# 50%      4.091825e+08
# 75%      6.800000e+08
# max      1.600000e+10
# Name: Valor, dtype: float64

# %%
inmuebles_area = inmuebles.Area.value_counts()
inmuebles_area
inmuebles_area.head().plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_group = inmuebles.groupby(('Barrio'))[['Area']].mean()
inmuebles_group
inmuebles_group.head(20).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# Alura clase 2 🐍

# %%
inmuebles.sample(20)
# Out:
#                      Tipo                                    Descripcion  \
# 9438                 Casa                          Casa en venta en Usme
# 5517  Oficina/Consultorio  Oficina/Consultorio en venta en Santa Barbara
# 445           Apartamento                Apartamento en venta en Kennedy
# 7590          Apartamento         Apartamento en venta en Chapinero Alto
# 1174          Apartamento            Apartamento en venta en Teusaquillo
# 1230          Apartamento                Apartamento en venta en Usaquén
# 2273          Apartamento         Apartamento en venta en Barrios Unidos
# 7110          Apartamento              Apartamento en venta en Barrancas
# 5828                 Casa                      Casa en venta en Fontibón
# 2944          Apartamento                   Apartamento en venta en Bosa
# 6868          Apartamento                Apartamento en venta en Usaquén
# 1106          Apartamento          Apartamento en venta en Santa Barbara
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 595.1+ KB

# %%
type(inmuebles.Valor[0])
# Out:
# numpy.int64

# %%
inmuebles.sample(20)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5745  Apartamento         Apartamento en venta en Los Rosales             2
# 5562  Apartamento             Apartamento en venta en Kennedy             3
# 3865  Apartamento     Apartamento en venta en Chico Reservado             3
# 5378  Apartamento                Apartamento en venta en Bosa             3
# 2503  Apartamento      Apartamento en venta en Barrios Unidos             2
# 6954  Apartamento                Apartamento en venta en Suba             3
# 9282  Apartamento      Apartamento en venta en Ciudad Salitre             2
# 8492  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 4170  Apartamento            Apartamento en venta en Fontibón             2
# 7871  Apartamento                Apartamento en venta en Suba             7
# 3254         Casa                    Casa en venta en Usaquén             2
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 595.1+ KB

# %%
inmuebles['Valor'].sum()
# Out:
# 5731633605583

# %%
inmuebles[['Valor','Barrio']]
# Out:
#            Valor                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['Precio_Millon'] = inmuebles.Valor.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   int64
#  8   Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 669.5+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area         Valor  Precio_Millon
# count   9520.000000  9520.000000    9520.000000  9.520000e+03    9520.000000
# mean       3.072479     2.447899     146.664706  6.020624e+08     602.062354
# std        2.049856     1.255314    1731.379622  7.046021e+08     704.602062
# min        1.000000     0.000000       2.000000  6.000000e+07      60.000000
# 25%        2.000000     2.000000      57.000000  2.500000e+08     250.000000
# 50%        3.000000     2.000000      80.000000  4.091825e+08     409.182500
# 75%        3.000000     3.000000     135.000000  6.800000e+08     680.000000
# max      110.000000     9.000000  166243.000000  1.600000e+10   16000.000000

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area          Valor  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00        9520.00
# mean           3.07    2.45    146.66   602062353.53         602.06
# std            2.05    1.26   1731.38   704602061.61         704.60
# min            1.00    0.00      2.00    60000000.00          60.00
# 25%            2.00    2.00     57.00   250000000.00         250.00
# 50%            3.00    2.00     80.00   409182500.00         409.18
# 75%            3.00    3.00    135.00   680000000.00         680.00
# max          110.00    9.00 166243.00 16000000000.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ      Valor  Precio_Millon
# 897  Usaquén  480000000         480.00

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area          Valor  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00        9520.00
# mean           3.07    2.45    146.66   602062353.53         602.06
# std            2.05    1.26   1731.38   704602061.61         704.60
# min            1.00    0.00      2.00    60000000.00          60.00
# 25%            2.00    2.00     57.00   250000000.00         250.00
# 50%            3.00    2.00     80.00   409182500.00         409.18
# 75%            3.00    3.00    135.00   680000000.00         680.00
# max          110.00    9.00 166243.00 16000000000.00       16000.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion valores precios inmuebles Bogota')
plt.xlim((50,1000))
plt.ylim((0,20))
plt.savefig('/content/drive/MyDrive/images/valor_inmuebles.png',format='png')
plt.show()

# %% [markdown]
# DESAFIOS CLASE 2 🏠

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles[['Tipo','Precio_Millon']]
# Out:
#              Tipo  Precio_Millon
# 0     Apartamento         360.00
# 1            Casa         670.00
# 2     Apartamento        1120.00
# 3     Apartamento         890.00
# 4     Apartamento         970.00
# ...           ...            ...
# 9515  Apartamento         290.00
# 9516  Apartamento         670.00
# 9517        Local         900.00
# 9518         Casa         335.00
# 9519  Apartamento         144.99
#
# [9520 rows x 2 columns]

# %%
df_tipo_preciomillon = inmuebles[['Tipo','Precio_Millon']]
df_tipo_preciomillon
# Out:
#              Tipo  Precio_Millon
# 0     Apartamento         360.00
# 1            Casa         670.00
# 2     Apartamento        1120.00
# 3     Apartamento         890.00
# 4     Apartamento         970.00
# ...           ...            ...
# 9515  Apartamento         290.00
# 9516  Apartamento         670.00
# 9517        Local         900.00
# 9518         Casa         335.00
# 9519  Apartamento         144.99
#
# [9520 rows x 2 columns]

# %%
inmuebles_tipo_filtrado = df_tipo_preciomillon.drop(df_tipo_preciomillon[~df_tipo_preciomillon['Tipo'].isin(['Casa', 'Apartamento', 'Finca', 'Local'])].index)
inmuebles_tipo_filtrado
# Out:
#              Tipo  Precio_Millon
# 0     Apartamento         360.00
# 1            Casa         670.00
# 2     Apartamento        1120.00
# 3     Apartamento         890.00
# 4     Apartamento         970.00
# ...           ...            ...
# 9515  Apartamento         290.00
# 9516  Apartamento         670.00
# 9517        Local         900.00
# 9518         Casa         335.00
# 9519  Apartamento         144.99
#
# [9419 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles_tipo_filtrado, x='Precio_Millon', kde=True, y='Tipo')
grafica.set_title('Distribucion valores precios inmuebles Bogota por tipo')
plt.xlim((50,3000))
plt.ylim((0,20))
plt.savefig('/content/drive/MyDrive/images/valor_inmuebles_por_tipo_tipovsprecio.png',format='png')
plt.show()

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles_tipo_filtrado, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion valores precios inmuebles Bogota por tipo')
plt.xlim((50,3000))
plt.ylim((0,100))
plt.savefig('/content/drive/MyDrive/images/valor_inmuebles_por_tipo.png',format='png')
plt.show()

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles['Precio_Metro_cuadrado_Barrio'] = inmuebles['Precio_Millon'] / inmuebles['Area']

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
barrios_caros = inmuebles.groupby('Barrio')['Precio_Metro_cuadrado_Barrio'].mean()

# %%
barrios_caros
# Out:
# Barrio
# Alameda              5.98
# Alhambra             4.33
# Andes Norte          6.05
# Antonio Nariño       3.53
# Barrancas            4.42
#                      ...
# Villa Maria          2.04
# Villas De Granada    3.17
# Villemar             3.99
# Zona Franca          2.96
# Zona Noroccidental   4.62
# Name: Precio_Metro_cuadrado_Barrio, Length: 149, dtype: float64

# %%
barrios_caros = barrios_caros.sort_values(ascending=False)
barrios_caros
# Out:
# Barrio
# El Virrey       10.20
# Santa Ana        9.36
# La Merced        8.98
# Chico Norte      8.54
# Los Rosales      8.17
#                  ...
# Santa Librada    1.95
# Las Ferias       1.72
# Libertador       1.66
# Roma             1.35
# Bosa Piamonte    1.18
# Name: Precio_Metro_cuadrado_Barrio, Length: 149, dtype: float64

# %%
barrios_caros_graf = barrios_caros.head(20)
barrios_caros_graf
# Out:
# Barrio
# El Virrey           10.20
# Santa Ana            9.36
# La Merced            8.98
# Chico Norte          8.54
# Los Rosales          8.17
# El Refugio           7.96
# Las Nieves           7.89
# El Retiro            7.72
# Chico Reservado      7.61
# Chapinero            7.43
# Salitre              7.24
# El Castillo          7.21
# Ciudad Salitre       7.19
# El Chicó             7.19
# La Candelaria        7.13
# Chapinero Alto       7.11
# Santa Fe             6.82
# Chapinero Central    6.81
# Prado Veraniego      6.80
# San Patricio         6.76
# Name: Precio_Metro_cuadrado_Barrio, dtype: float64

# %%
barrios_baratos_graf = barrios_caros.tail(20)
barrios_baratos_graf
# Out:
# Barrio
# Zona Franca             2.96
# Tunjuelito              2.82
# Costa Azul              2.81
# Galicia                 2.81
# Bosa                    2.81
# Quirigua                2.78
# La Sabana               2.77
# Bellavista Occidental   2.77
# La Estancia             2.70
# Timiza                  2.67
# Buenos Aires            2.60
# Las Delicias            2.59
# Ingles                  2.50
# Estrada                 2.38
# Villa Maria             2.04
# Santa Librada           1.95
# Las Ferias              1.72
# Libertador              1.66
# Roma                    1.35
# Bosa Piamonte           1.18
# Name: Precio_Metro_cuadrado_Barrio, dtype: float64

# %% [markdown]
# CLASE 3 ALURA LATAM

# %%
inmuebles.groupby('Barrio').mean()
# Out:
# <ipython-input-146-7fb844af9b3c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean()
#                     Habitaciones  Banos   Area        Valor  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00  97.00 580000000.00         580.00
# Alhambra                    3.00   2.94 190.41 752352941.18         752.35
# Andes Norte                 3.00   2.86 124.86 709571428.57         709.57
# Antonio Nariño              4.31   2.50 163.06 459221875.00         459.22
# Barrancas                   2.87   2.13  70.20 314133333.33         314.13
# ...                          ...    ...    ...          ...            ...
# Villa Maria                 4.69   3.69 207.15 402846153.85         402.85
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
# <ipython-input-147-45bba8259daf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area         Valor  Precio_Millon  \
# Barrio
# Alameda                        3      2      97     580000000         580.00
# Alhambra                      51     50    3237   12790000000       12790.00
# Andes Norte                   21     20     874    4967000000        4967.00
# Antonio Nariño               207    120    7827   22042650000       22042.65
# Barrancas                     43     32    1053    4712000000        4712.00
# ...                          ...    ...     ...           ...            ...
# Villa Maria                   61     48    2693    5237000000        5237.00
# ...

# %%
datos_barrio['Valor_M2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area         Valor  Precio_Millon  \
# Barrio
# Alameda                        3      2      97     580000000         580.00
# Alhambra                      51     50    3237   12790000000       12790.00
# Andes Norte                   21     20     874    4967000000        4967.00
# Antonio Nariño               207    120    7827   22042650000       22042.65
# Barrancas                     43     32    1053    4712000000        4712.00
# ...                          ...    ...     ...           ...            ...
# Villa Maria                   61     48    2693    5237000000        5237.00
# Villas De Granada             76     51    1905    6210625000        6210.62
# Villemar                      53     37    1384    5469000000        5469.00
# Zona Franca                    2      1      54     160000000         160.00
# Zona Noroccidental          2778   2204  119084  544453061408      544453.06
#
# ...

# %%
#pasar valor m2 barrio a inmuebles o dataset original mediante diccionoario
dict(datos_barrio['Valor_M2_Barrio'])
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %%
m2_barrio = dict(datos_barrio['Valor_M2_Barrio'])
m2_barrio
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %%
inmuebles['Valor_M2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_M2_Barrio'] = inmuebles['Valor_M2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#         Valor  Precio_Millon  Precio_Metro_cuadrado_Barrio  Valor_M2_Barrio
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
#Barrio ya no es mas el indice, ahora es una columna
# Out:
#                  Barrio  Habitaciones  Banos    Area         Valor  \
# 0               Alameda             3      2      97     580000000
# 1              Alhambra            51     50    3237   12790000000
# 2           Andes Norte            21     20     874    4967000000
# 3        Antonio Nariño           207    120    7827   22042650000
# 4             Barrancas            43     32    1053    4712000000
# ..                  ...           ...    ...     ...           ...
# 144         Villa Maria            61     48    2693    5237000000
# 145   Villas De Granada            76     51    1905    6210625000
# 146            Villemar            53     37    1384    5469000000
# 147         Zona Franca             2      1      54     160000000
# 148  Zona Noroccidental          2778   2204  119084  544453061408
#
#      Precio_Millon  Precio_Metro_cuadrado_Barrio  Valor_M2_Barrio
# 0           580.00                          5.98             5.98
# ...

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area         Valor  \
# 5        Barrios Unidos          1525   1196   87799  259877762703
# 10                 Bosa          1743    789   34879   93400560494
# 22             Cedritos          1458   1348   53711  270027733421
# 24            Chapinero           892    913   81248  372130933118
# 50             Engativa          1676   1077   59808  172711728232
# 63              Kennedy          2151   1233   61475  207963648911
# 125       Santa Barbara          1073   1162   54693  320097803000
# 132                Suba          1497   1202   61615  266406040022
# 138             Usaquén          3109   3044  148121  837710365000
# 148  Zona Noroccidental          2778   2204  119084  544453061408
#
#      Precio_Millon  Precio_Metro_cuadrado_Barrio  Valor_M2_Barrio
# 5        259877.76                       2070.61             2.96
# 10        93400.56                       1654.36             2.68
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio', y='Valor_M2_Barrio', data=datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %%
#boxplot
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Metro_cuadrado_Barrio', data=inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Metro_cuadrado_Barrio', data=inmuebles.query('Barrio in @top_barrios & Precio_Metro_cuadrado_Barrio < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Area', data=inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data=inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()
